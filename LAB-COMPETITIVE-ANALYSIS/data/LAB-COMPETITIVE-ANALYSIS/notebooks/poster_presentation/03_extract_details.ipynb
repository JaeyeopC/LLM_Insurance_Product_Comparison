# %%
import os

os.environ["OPENAI_API_KEY"] = "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"

# %%
# Cell 1: Extract Details (Prompt V1 - Weak Prompt)

import os
import json
from langchain.prompts import PromptTemplate
from langchain.chat_models import ChatOpenAI

def load_prompt_from_file(prompt_file: str) -> str:
    """Utility function to load prompt text from a file."""
    with open(prompt_file, 'r', encoding='utf-8') as pf:
        return pf.read()

def extract_full_details_realtime(
    base_dir: str,
    output_dir: str,
    output_prefix: str,
    chat_model,
    prompt_file: str
):
    """
    Traverses `base_dir` (each top-level subfolder is a 'company'),
    processes all .md files in real-time, writing extracted info to
    separate JSON files in `output_dir`.

    For each company:
      - Creates (or appends to) a JSON file named "{output_prefix}_{company_name}.json"
      - After each .md file is processed, the data is written immediately.
    """
    # Make sure output_dir exists
    os.makedirs(output_dir, exist_ok=True)

    # Load the prompt content
    prompt_text = load_prompt_from_file(prompt_file)
    prompt = PromptTemplate(input_variables=["content"], template=prompt_text)

    for company_folder in os.listdir(base_dir):
        company_path = os.path.join(base_dir, company_folder)

        # Process only directories
        if not os.path.isdir(company_path):
            continue

        print(f"\n=== Processing Company: {company_folder} ===")

        # Prepare the company's JSON output file
        company_json_filename = f"{output_prefix}_{company_folder}.json"
        company_json_path = os.path.join(output_dir, company_json_filename)

        # If a JSON file already exists, load it to avoid overwriting
        if os.path.exists(company_json_path):
            with open(company_json_path, 'r', encoding='utf-8') as f:
                company_data = json.load(f)
        else:
            company_data = {}

        # Recursively walk the company's folder
        for root, dirs, files in os.walk(company_path):
            for filename in files:
                if filename.endswith(".md"):
                    file_path = os.path.join(root, filename)
                    rel_path = os.path.relpath(file_path, company_path)

                    try:
                        with open(file_path, 'r', encoding='utf-8') as file:
                            markdown_content = file.read()

                        # Format the LLM prompt
                        formatted_prompt = prompt.format(content=markdown_content)
                        # Get model response
                        response = chat_model.predict(formatted_prompt).strip()

                        # Parse response
                        product_name = None
                        details = []

                        for line in response.splitlines():
                            if line.startswith("Produktname:"):
                                product_name = line.replace("Produktname:", "").strip()
                            elif line.startswith("- "):
                                details.append(line[2:].strip())

                        company_data[rel_path] = {
                            "product_name": product_name,
                            "details": details
                        }

                        # Write out the JSON immediately after each file
                        with open(company_json_path, 'w', encoding='utf-8') as out_f:
                            json.dump(company_data, out_f, ensure_ascii=False, indent=4)

                        print(f"Extrahiert aus {rel_path} => Produkt: {product_name}, Details: {len(details)} Einträge")

                    except Exception as e:
                        print(f"Fehler beim Verarbeiten der Datei {rel_path}: {e}")

        print(f"→ Gesamte Ergebnisse für {company_folder} in: {company_json_path}")

# -------------------------------------------------------------------
# MAIN EXECUTION FOR PROMPT V1
# -------------------------------------------------------------------
BASE_DIR_V1 = "03_textbinary_products_v1"
OUTPUT_DIR_V1 = "04_product_details_extraction_v1"
OUTPUT_PREFIX_V1 = "report_full_details_v1"  # => e.g. "report_full_details_v1_arag.json", etc.
PROMPT_FILE_V1 = "extract_full_details_prompt_v1.txt"

chat_model_v1 = ChatOpenAI(model="gpt-4o", temperature=0)

print("=== Extracting with Prompt V1 (Weak Prompt) ===")
extract_full_details_realtime(
    base_dir=BASE_DIR_V1,
    output_dir=OUTPUT_DIR_V1,
    output_prefix=OUTPUT_PREFIX_V1,
    chat_model=chat_model_v1,
    prompt_file=PROMPT_FILE_V1
)
# Out:
# === Extracting with Prompt V1 (Weak Prompt) ===
#
# === Processing Company: generali ===
# Extrahiert aus privatkunden_rundum-schutz_young-and-drive.md => Produkt: Generali Protect Me App, Details: 22 Einträge
# Extrahiert aus service-kontakt_apps_generali-protect-me-app.md => Produkt: Generali Protect Me App, Details: 23 Einträge
# Extrahiert aus geschaeftskunden_gesundheit-betriebliche-vorsorge_betriebliche-krankenversicherung-inland.md => Produkt: Business+ Die betriebliche Krankenversicherung der Generali, Details: 12 Einträge
# Extrahiert aus privatkunden_gesundheit-freizeit_unfallversicherung_unfall-assistance-xxl.md => Produkt: Kinderunfallversicherung, Details: 20 Einträge
# Extrahiert aus privatkunden_gesundheit-freizeit_reise-krankenversicherung.md => Produkt: None, Details: 22 Einträge
# Extrahiert aus privatkunden_gesundheit-freizeit_wassersportversicherung.md => Produkt: Generali Protect Me App, Details: 16 Einträge
# Extrahiert aus geschaeftskunden_geschaeft-gebaeude_ertragsausfallversicherung.md => Produkt: Ertragsausfallversicherung, Details: 16 Einträge
# Extrahiert aus privatkunden_fahrzeug-zuhause_hausratversicherung.md => Produkt: Hausratversicherung Optimal, Details: 15 Einträge
# Extrahiert aus geschaeftskunden_waren-transport_tiefkuehlgutversicherung.md => Produkt: Tiefkühlgutversicherung, Details: 15 Einträge
# Extrahiert aus geschaeftskunden_gesundheit-betriebliche-vorsorge_direktversicherung.md => Produkt: Generali GesundheitsApp, Details: 23 Einträge
# Extrahiert aus geschaeftskunden_geschaeft-gebaeude_sach-inhaltsversicherung.md => Produkt: Fairster Firmenversicherer, Details: 19 Einträge
# Extrahiert aus privatkunden_vorsorge-finanzen_sofort-rente.md => Produkt: Generali VitalityApp, Details: 15 Einträge
# Extrahiert aus geschaeftskunden_waren-transport_gewerbe-kompakt-mobil.md => Produkt: Generali Protect Me App, Details: 31 Einträge
# Extrahiert aus privatkunden_recht-haftung_rechtsschutzversicherung.md => Produkt: Young & Home, Details: 14 Einträge
# Extrahiert aus geschaeftskunden_geschaeft-gebaeude_elektronikversicherung.md => Produkt: Elektronikversicherung, Details: 20 Einträge
# Extrahiert aus geschaeftskunden_geschaeft-gebaeude_bauversicherungen.md => Produkt: Generali Protect Me App, Details: 21 Einträge
# Extrahiert aus privatkunden_gesundheit-freizeit_freizeit-versicherung.md => Produkt: Generali Protect Me App, Details: 17 Einträge
# Extrahiert aus geschaeftskunden_waren-transport_warenversicherung.md => Produkt: Generali Protect Me App, Details: 18 Einträge
# Extrahiert aus geschaeftskunden_geschaeft-gebaeude_firmenrechtsschutzversicherung.md => Produkt: Generali VitalityApp, Details: 15 Einträge
# Extrahiert aus privatkunden_vorsorge-finanzen_risikolebensversicherung.md => Produkt: Sterbegeldversicherung, Details: 14 Einträge
# Extrahiert aus privatkunden_vorsorge-finanzen_parkdepot-flex.md => Produkt: Generali VitalityApp, Details: 22 Einträge
# Extrahiert aus privatkunden_gesundheit-freizeit_pflegezusatzversicherung.md => Produkt: Pflegeleichte Vorsorge – mit staatlicher Förderung im Tarif PflegeBahr, Details: 41 Einträge
# Extrahiert aus privatkunden_vorsorge-finanzen_goldanlage.md => Produkt: None, Details: 19 Einträge
# Extrahiert aus privatkunden_fahrzeug-zuhause_elektro-fahrzeuge.md => Produkt: Generali Protect Me App, Details: 14 Einträge
# Extrahiert aus geschaeftskunden_geschaeft-gebaeude_photovoltaik-versicherung.md => Produkt: Photovoltaikversicherung, Details: 19 Einträge
# Extrahiert aus privatkunden_gesundheit-freizeit_beitragsentlastung-im-alter.md => Produkt: Generali GesundheitsApp, Details: 20 Einträge
# Extrahiert aus privatkunden_gesundheit-freizeit_krankenhaustagegeld.md => Produkt: Generali GesundheitsApp, Details: 18 Einträge
# Extrahiert aus privatkunden_gesundheit-freizeit_krankenzusatzversicherung.md => Produkt: Generali GesundheitsApp, Details: 29 Einträge
# Extrahiert aus privatkunden_fahrzeug-zuhause_photovoltaikversicherung.md => Produkt: Photovoltaikversicherung, Details: 11 Einträge
# Extrahiert aus privatkunden_rundum-schutz_vermoegensaufbau4you.md => Produkt: Generali VitalityApp, Details: 15 Einträge
# Extrahiert aus geschaeftskunden_gesundheit-betriebliche-vorsorge_auslands-gruppenversicherung.md => Produkt: Generali GesundheitsApp, Details: 18 Einträge
# Extrahiert aus privatkunden_vorsorge-finanzen_bausparen-finanzieren.md => Produkt: Generali VitalityApp, Details: 41 Einträge
# Extrahiert aus geschaeftskunden_rundum-schutz_landwirtschaft.md => Produkt: Generali Protect Me App, Details: 22 Einträge
# Extrahiert aus privatkunden_rundum-schutz_young-and-home.md => Produkt: Generali Protect Me App, Details: 30 Einträge
# Extrahiert aus privatkunden_fahrzeug-zuhause
# Extrahiert aus geschaeftskunden_waldversicherung.md => Produkt: Waldversicherung, Details: 9 Einträge
# Extrahiert aus pk_haftpflicht_p_bauherrenhaftpflicht.md => Produkt: Bauherrenhaftpflicht, Details: 9 Einträge
# Extrahiert aus geschaeftskunden_betriebsgebaeudeversicherung.md => Produkt: Gebäudeversicherung für Betriebe, Details: 11 Einträge
# Extrahiert aus geschaeftskunden_autoinhaltsversicherung.md => Produkt: Autoinhaltsversicherung, Details: 9 Einträge
# Extrahiert aus pk_kfz_p_roller-versicherung.md => Produkt: Roller-Versicherung, Details: 10 Einträge
# Extrahiert aus geschaeftskunden_betriebliche-krankenversicherung.md => Produkt: FlexMed Gesundheitsbausteine, Details: 21 Einträge
# Extrahiert aus pk_haftpflicht_p_rechtsschutz.md => Produkt: Rechtsschutzversicherung bei AXA, Details: 15 Einträge
# Extrahiert aus geschaeftskunden_ertragsausfallversicherung.md => Produkt: Ertragsausfallversicherung, Details: 12 Einträge
# Extrahiert aus geschaeftskunden_betriebliche-altersversorgung.md => Produkt: Kölner Spezial Beratungs-GmbH, Details: 81 Einträge
# Extrahiert aus geschaeftskunden_finanzierungsloesungen_factoring.md => Produkt: Factoring von AXA, Details: 18 Einträge
# Extrahiert aus pk_kfz_p_oldtimer-versicherung.md => Produkt: Oldtimer-Versicherung, Details: 17 Einträge
# Extrahiert aus geschaeftskunden_luftfahrtversicherung.md => Produkt: Profi-Schutz, Details: 25 Einträge
# Extrahiert aus pk_haftpflicht_p_verkehrsrechtsschutz.md => Produkt: Verkehrsrechtsschutzversicherung, Details: 17 Einträge
# Extrahiert aus pk_existenzsicherung_p_unfallversicherung.md => Produkt: Unfallversicherung von AXA, Details: 15 Einträge
# Extrahiert aus pk_existenzsicherung_p_berufsunfaehigkeitsversicherung.md => Produkt: Berufsunfähigkeitsversicherung von AXA, Details: 18 Einträge
# Extrahiert aus geschaeftskunden_praxisausfallversicherung.md => Produkt: Praxisausfallversicherung, Details: 9 Einträge
# Extrahiert aus geschaeftskunden_cyber-versicherung.md => Produkt: Cyber-Versicherung, Details: 20 Einträge
# Extrahiert aus pk_gesundheit_p_private-krankenversicherung.md => Produkt: Private Krankenversicherung, Details: 22 Einträge
# Extrahiert aus geschaeftskunden_transportversicherung.md => Produkt: AXA International Services, Details: 20 Einträge
# Extrahiert aus geschaeftskunden_internationale-krankenversicherung.md => Produkt: Internationale Krankenversicherung, Details: 11 Einträge
# Extrahiert aus geschaeftskunden_bauleistungsversicherung.md => Produkt: Bauleistungsversicherung, Details: 20 Einträge
# Extrahiert aus geschaeftskunden_industrie-sachversicherung.md => Produkt: Industrie Select Sach und Ertragsausfall Versicherung, Details: 11 Einträge
# Extrahiert aus geschaeftskunden_vermoegensschadenhaftpflicht.md => Produkt: Vertrauensschadenversicherung, Details: 37 Einträge
# Extrahiert aus geschaeftskunden_inhaltsversicherung.md => Produkt: Inhaltsversicherung für Betriebe, Details: 9 Einträge
# Extrahiert aus pk_kfz_p_e-scooter-versicherung.md => Produkt: E-Scooter Versicherung, Details: 13 Einträge
# Extrahiert aus pk_haftpflicht.md => Produkt: AXA in Social Media, Details: 90 Einträge
# Extrahiert aus pk_gesundheit_p_pflegezusatzversicherung.md => Produkt: Pflege-Bahr Versicherung, Details: 21 Einträge
# Extrahiert aus geschaeftskunden_montageversicherung.md => Produkt: Montageversicherung, Details: 9 Einträge
# Extrahiert aus pk_haus-wohnung_p_elementarversicherung.md => Produkt: Elementarversicherung von AXA, Details: 11 Einträge
# Extrahiert aus pk_gesundheit_p_auslandskrankenversicherung.md => Produkt: Auslandskrankenversicherung, Details: 11 Einträge
# Extrahiert aus geschaeftskunden_verkehrshaftungsversicherung.md => Produkt: Verkehrshaftungsversicherung, Details: 10 Einträge
# Extrahiert aus geschaeftskunden_finanzierungsloesungen_firmenleasing.md => Produkt: Firmenleasing, Details: 10 Einträge
# Extrahiert aus pk_haus-wohnung_p_gebaeudeversicherung.md => Produkt: Wohngebäudeversicherung von AXA, Details: 17 Einträge
# Extrahiert aus pk_gesundheit_p_zahnzusatzversicherung.md => Produkt: Zahnzusatzversicherung, Details: 10 Einträge
# Extrahiert aus geschaeftskunden_maschinenversicherung.md => Produkt: Maschinenversicherung, Details: 5 Einträge
# Extrahiert aus pk_altersvorsorge_p_private-rentenversicherung.md => Produkt: Private Rentenversicherung, Details: 32 Einträge
# Extrahiert aus pk_haus-wohnung_p_bausparvertrag.md => Produkt: Bausparen mit AXA, Details: 13 Einträge
# Extrahiert aus pk_gesundheit_p_krankentagegeld-versicherung.md => Produkt: Krankentagegeld-Versicherung Krankengeld easy, Details: 11 Einträge
# Extrahiert aus pk_existenzsicherung_p_sterbegeld-versicherung.md => Produkt: Sterbegeldversicherung, Details: 12 Einträge
# Extrahiert aus pk_altersvorsorge_p_vermoegenswirksame-leistungen.md => Produkt: Vermögenswirksame Leistungen, Details: 15 Einträge
# Extrahiert aus geschaeftskunden_betriebshaftpflicht.md => Produkt: Betriebshaftpflichtversicherung von AXA, Details: 16 Einträge
# Extrahiert aus pk_haftpflicht_p_haus-grundbesitzerhaftpflicht.md => Produkt: Haus- und Grundbesitzerhaftpflicht von AXA, Details: 16 Einträge
# Extrahiert aus pk_haftpflicht_p_tierhalter-haftpflicht.md => Produkt: Tierhalterhaftpflichtversicherung von AXA, Details: 25 Einträge
# Extrahiert aus geschaeftskunden_elektronikversicherung.md => Produkt: Elektronikversicherung, Details: 7 Einträge
# Extrahiert aus geschaeftskunden_industrie-haftpflichtversicherung.md => Produkt: Industrie Select Haftpflichtversicherung, Details: 11 Einträge
# Extrahiert aus pk_altersvorsorge_p_betriebliche-altersvorsorge.md => Produkt: Selbstständige Berufsunfähigkeitsversicherung, Details: 75 Einträge
# Extrahiert aus pk_gesundheit_p_krankenhauszusatzversicherung.md => Produkt: Krankenhauszusatzversicherung, Details: 17 Einträge
# Extrahiert aus pk_gesundheit_p_ambulante-zusatzversicherung.md => Produkt: Ambulante Zusatzversicherung von AXA, Details: 14 Einträge
# Extrahiert aus geschaeftskunden_berufshaftpflicht.md => Produkt: Vertrauensschadenversicherung, Details: 19 Einträge
# Extrahiert aus pk_kfz_p_elektroauto-versicherung.md => Produkt: Elektroauto-Versicherung von AXA, Details: 14 Einträge
# Extrahiert aus pk_haus-wohnung_p_hausratversicherung.md => Produkt: Hausratversicherung von AXA, Details: 18 Einträge
# Extrahiert aus geschaeftskunden_rechtsschutzversicherung.md => Produkt: JurContract, Details: 77 Einträge
# Extrahiert aus geschaeftskunden_kautionsversicherung.md => Produkt: Bürgschaftsversicherung von AXA, Details: 13 Einträge
# Extrahiert aus pk_haftpflicht_p_gewaesserschadenhaftpflicht.md => Produkt: Gewässerschadenhaftpflichtversicherung, Details: 10 Einträge
# Extrahiert aus pk_gesundheit_p_reiseversicherung.md => Produkt: AXA Reiseversicherung, Details: 10 Einträge
# Extrahiert aus pk_existenzsicherung_p_risikolebensversicherung.md => Produkt: Risikolebensversicherung von AXA, Details: 17 Einträge
# Extrahiert aus geschaeftskunden_internationale-versicherungsprogramme.md => Produkt: Industrie Select Haftpflicht-Versicherung, Details: 68 Einträge
# Extrahiert aus pk_kfz_p_motorradversicherung.md => Produkt: Motorradversicherung von AXA, Details: 17 Einträge
# Extrahiert aus pk_altersvorsorge.md => Produkt: None, Details: 22 Einträge
# Extrahiert aus geschaeftskunden_vertrauensschadenversicherung.md => Produkt: Vertrauensschadenversicherung, Details: 13 Einträge
# Extrahiert aus geschaeftskunden_profi-schutz-absicherung.md => Produkt: Maschinenversicherung, Details: 69 Einträge
# Extrahiert aus pk_haftpflicht_p_private-haftpflichtversicherung.md => Produkt: Private Haftpflichtversicherung von AXA, Details: 13 Einträge
# Extrahiert aus pk_haus-wohnung_p_baufinanzierung.md => Produkt: Vermögenswirksame Leistungen, Details: 198 Einträge
# Extrahiert aus geschaeftskunden_mitarbeiterabsicherung.md => Produkt: Betriebliche Gruppenunfallversicherung, Details: 56 Einträge
# Extrahiert aus pk_kfz_p_lieferwagen-versicherung.md => Produkt: Lieferwagen-Versicherung, Details: 17 Einträge
# Extrahiert aus geschaeftskunden_kfz-flottenversicherung.md => Produkt: Kfz-Flottenversicherung, Details: 13 Einträge
# Extrahiert aus pk_kfz_p_kfz-versicherung.md => Produkt: Smart Repair, Details: 26 Einträge
# → Gesamte Ergebnisse für axa in: 04_product_details_extraction_v1/report_full_details_v1_axa.json
#
# === Processing Company: arag ===
# Extrahiert aus haftpflichtversicherung.md => Produkt: ARAG Schaden-Service, Details: 24 Einträge
# Extrahiert aus gewerbeversicherung_betriebshaftpflichtversicherung.md => Produkt: Betriebshaftpflichtversicherung, Details: 14 Einträge
# Extrahiert aus rechtsschutzversicherung_mietrechtsschutz.md => Produkt: Mietrechtsschutz, Details: 13 Einträge
# Extrahiert aus reiseversicherung_top-schutzbrief.md => Produkt: ARAG Top-Schutzbrief, Details: 12 Einträge
# Extrahiert aus unfallversicherung.md => Produkt: ARAG Unfallversicherung, Details: 19 Einträge
# Extrahiert aus zahnzusatzversicherung.md => Produkt: ARAG Zahnzusatzversicherung, Details: 14 Einträge
# Extrahiert aus krankenzusatzversicherung_krankentagegeldversicherung.md => Produkt: Krankentagegeld, Details: 12 Einträge
# Extrahiert aus hausratversicherung_fahrradversicherung.md => Produkt: ARAG Fahrradversicherung, Details: 13 Einträge
# Extrahiert aus rechtsschutzversicherung_familienrechtsschutz.md => Produkt: ARAG Familienrechtsschutzversicherung, Details: 15 Einträge
# Extrahiert aus unfallversicherung_existenz-schutz.md => Produkt: ARAG Existenz-Schutz, Details: 12 Einträge
# Extrahiert aus gewerbeversicherung_ertragsausfallversicherung.md => Produkt: ARAG Recht & Gewerbe, Details: 23 Einträge
# Extrahiert aus tierversicherung_hunde-op-versicherung.md => Produkt: ARAG Hunde-OP-Versicherung, Details: 16 Einträge
# Extrahiert aus rechtsschutzversicherung_rechtsschutz-scheidung.md => Produkt: ARAG Ehe-Rechtsschutz, Details: 8 Einträge
# Extrahiert aus gewerbeversicherung.md => Produkt: Betriebliche Krankenversicherung, Details: 43 Einträge
# Extrahiert aus hausratversicherung.md => Produkt: ARAG Hausratversicherung, Details: 19 Einträge
# Extrahiert aus rechtsschutzversicherung_versicherungspaket.md => Produkt: ARAG Recht und Heim, Details: 13 Einträge
# Extrahiert aus gewerbeversicherung_forderungsausfallversicherung.md => Produkt: Forderungsmanagement, Details: 11 Einträge
# Extrahiert aus vereinsversicherung_karneval-versicherung.md => Produkt: None, Details: 28 Einträge
# Extrahiert aus krankenzusatzversicherung_kinder.md => Produkt: Krankenzusatzversicherung für Kinder, Details: 14 Einträge
# Extrahiert aus gewerbeversicherung_manager-rechtsschutz.md => Produkt: Manager-Rechtsschutz, Details: 14 Einträge
# Extrahiert aus tierversicherung_katzen-op-versicherung.md => Produkt: ARAG Katzen-OP-Versicherung, Details: 16 Einträge
# Extrahiert aus hausratversicherung_elementarversicherung.md => Produkt: Elementarversicherung, Details: 10 Einträge
# Extrahiert aus rechtsschutzversicherung_erb-rechtsschutz.md => Produkt: Premium-Rechtsschutz mit Erb-Rechtsschutz, Details: 14 Einträge
# Extrahiert aus gewerbeversicherung_betriebliche-krankenversicherung.md => Produkt: Betriebliche Krankenversicherung (bKV), Details: 10 Einträge
# Extrahiert aus vereinsversicherung.md => Produkt: Kfz-Zusatzversicherung, Details: 12 Einträge
# Extrahiert aus gewerbeversicherung_inhaltsversicherung.md => Produkt: Inhaltsversicherung, Details: 13 Einträge
# Extrahiert aus krankenzusatzversicherung_krankenhauszusatzversicherung.md => Produkt: Krankenhauszusatzversicherung, Details: 15 Einträge
# Extrahiert aus rechtsschutzversicherung_juracheck.md => Produkt: ARAG JuraCheck, Details: 13 Einträge
# Extrahiert aus rechtsschutzversicherung_vermieterrechtsschutz.md => Produkt: Vermieterrechtsschutz, Details: 19 Einträge
# Extrahiert aus tierversicherung_hundekrankenversicherung.md => Produkt: ARAG Hundekrankenversicherung, Details: 19 Einträge
# Extrahiert aus gewerbeversicherung_werkverkehrsversicherung.md => Produkt: Werkverkehrsversicherung, Details: 14 Einträge
# Extrahiert aus reiseversicherung_campingversicherung.md => Produkt: ARAG Camper-Schutz, Details: 11 Einträge
# Extrahiert aus rechtsschutzversicherung_rechtsschutz-unterhalt.md => Produkt: Unterhaltsrechtsschutz, Details: 10 Einträge
# Extrahiert aus rechtsschutzversicherung.md => Produkt: ARAG Rechtsschutzversicherung, Details: 14 Einträge
Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_gesundheit_pflege_pflegesofort.xhtml.md => Produkt: PflegeSofort, Details: 24 Einträge
# Extrahiert aus deu_bde_geschaeftlich_bde_produkte_geschaeftskunde_bde_betrieb_haftpflicht_bde_rechtsschutz_2_rechtsschutz_geschaeftskunden.xhtml.md => Produkt: ROLAND, Details: 23 Einträge
# Extrahiert aus deu_bde_geschaeftlich_bde_produkte_geschaeftskunde_bde_gesundheit_1_bkv_gutschein_loesungen_gutscheinloesungen.xhtml.md => Produkt: CareWell Exclusive (Manager-Vorsorge), Details: 9 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_gesundheit_zusatzversicherungen_krankenhaus_uebersicht.xhtml.md => Produkt: Krankenhauszusatzversicherung Mehr Komfort, Details: 30 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_haus_haftpflicht_hausrat_hausrat_1.xhtml.md => Produkt: Hausratversicherung, Details: 13 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_gesundheit_uebersicht.xhtml.md => Produkt: Sterbegeldversicherung, Details: 41 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_gesundheit_zusatzversicherungen_zahn_uebersicht.xhtml_p0%3D334009.md => Produkt: Ausgezeichnete Zahnzusatzversicherung, Details: 17 Einträge
# Extrahiert aus deu_bde_privat_bde_unternehmen_bde_nachhaltigkeit_bde_nachhaltige_produkte_uebersicht_97.xhtml.md => Produkt: Kfz-Versicherung, Details: 21 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_gesundheit_kv_voll_primex.xhtml.md => Produkt: Kranken-Vollversicherung: einsA primex, Details: 30 Einträge
# Extrahiert aus deu_bde_geschaeftlich_bde_produkte_geschaeftskunde_bde_betrieb_haftpflicht_gewerbe_sachversicherung_uebersicht.xhtml.md => Produkt: Gewerbe-Sachversicherung, Details: 5 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_gesundheit_zusatzversicherungen_bde_bkk.xhtml.md => Produkt: Zusatzversicherungen für BKK-Versicherte, Details: 49 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_haus_haftpflicht_bde_rechtsschutz_1_uebersicht.xhtml.md => Produkt: Gute Gründe für ROLAND, Details: 19 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_gesundheit_pflege_deutsche_foerder_pflege.xhtml.md => Produkt: Deutsche-Förder-Pflege (Pflege-Bahr), Details: 14 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_rund_ums_tier_hunde_kv_hunde_kv.xhtml.md => Produkt: Hundekrankenversicherung, Details: 22 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_gesundheit_kv_voll_spezialtarife_heilfuersorge.xhtml.md => Produkt: Zusatzversicherungen zur Heilfürsorge, Details: 17 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_gesundheit_kv_voll_pflegepflichtversicherung_uebersicht.xhtml.md => Produkt: Pflege-Pflichtversicherung, Details: 22 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_gesundheit_zusatzversicherungen_ambulant_ak.xhtml.md => Produkt: Ergänzung für GKV-Versicherte mit Kostenerstattung, Details: 6 Einträge
# Extrahiert aus deu_bde_geschaeftlich_bde_produkte_geschaeftskunde_bde_betrieb_haftpflicht_bde_internetschutz_cyberrisiko_versicherung.xhtml.md => Produkt: Gewerbe-Cyberrisiko-Versicherung, Details: 13 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_gesundheit_zusatzversicherungen_option_uebersicht.xhtml.md => Produkt: Zusatzversicherung: Mehr Optionen, Details: 10 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_vorsorge_finanzen_existenzschutz_1_uebersicht.xhtml.md => Produkt: Weitere Informationen, Details: 13 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_gesundheit_zusatzversicherungen_ambulant_uebersicht.xhtml.md => Produkt: Ambulante Zusatzversicherung, Details: 19 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_gesundheit_kv_voll_spezialtarife_beamte.xhtml.md => Produkt: Private Krankenversicherung für Beamte, Details: 21 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_gesundheit_pflege_uebersicht.xhtml.md => Produkt: Pflegeversicherung, Details: 8 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_rund_ums_tier_hunde_op_hunde_op.xhtml.md => Produkt: Hunde-OP-Versicherung, Details: 15 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_vorsorge_finanzen_baufinanzierung_1_uebersicht.xhtml.md => Produkt: Ansprechpartner für bestehende Verträge, Details: 25 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_vorsorge_finanzen_versicherungen_fuer_kinder_1_uebersicht.xhtml.md => Produkt: Mehr Sehen, Details: 35 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_kfz_reisen_bde_mopedversicherung_mopedversicherung_und_mopedkennzeichen.xhtml.md => Produkt: Mopedversicherung und -Kennzeichen, Details: 7 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_gesundheit_kv_voll_spezialtarife_beamtenanwaerter.xhtml.md => Produkt: Private Krankenversicherung für Beamtenanwärter, Details: 14 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_gesundheit_unfallversicherung_private_unfallversicherung_private_unfall.xhtml.md => Produkt: Private Unfallversicherung, Details: 28 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_vorsorge_finanzen_grundfaehigkeitsversicherung_uebersicht.xhtml.md => Produkt: Grundfähigkeitsversicherung, Details: 19 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_rund_ums_tier_pferde_haftpflicht_pferdehalter.xhtml.md => Produkt: Pferdehaftpflichtversicherung, Details: 17 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_kfz_reisen_bde_rechtsschutz_rechtsschutz_privatkunden.xhtml.md => Produkt: Gute Gründe für ROLAND, Details: 19 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_gesundheit_unfallversicherung_uebersicht.xhtml.md => Produkt: UnfallhilfeSofort, Details: 19 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_kfz_reisen_kfz_versicherung_kfz_versicherung.xhtml.md => Produkt: Kfz-Versicherung, Details: 11 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_gesundheit_zusatzversicherungen_telearzt_3_mediapp_tarif.xhtml.md => Produkt: Barmenia MediApp-Tarif (Telearzt), Details: 9 Einträge
# Extrahiert aus deu_bde_geschaeftlich_bde_produkte_geschaeftskunde_bde_betrieb_haftpflicht_gewerbe_haftpflicht_1_ergaenzender_haftpflichtschutz_1_uebersicht.xhtml.md => Produkt: Haus- und Grundbesitzer-Haftpflichtversicherung, Details: 10 Einträge
# Extrahiert aus deu_bde_geschaeftlich_bde_produkte_geschaeftskunde_bde_vorsorge_finanzen_1_betriebliche_altersversorgung_uebersicht.xhtml.md => Produkt: DirektBU, Details: 19 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_gesundheit_kv_voll_spezialtarife_vhv.xhtml.md => Produkt: Kranken-Vollversicherung: Ärzte (VHV+), Details: 26 Einträge
# Extrahiert aus deu_bde_privat_bde_produkte_privat_bde_gesundheit_unfallversicherung_kiss_kiss.xhtml.md => Produkt: Kinderinvaliditätsversicherung KISS, Details: 13 Einträge
# ...
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/langchain_core/_api/deprecation.py:180, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     178     warned = True
#     179     emit_warning()
# --> 180 return wrapped(*args, **kwargs)
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/langchain_core/language_models/chat_models.py:1054, in BaseChatModel.predict(self, text, stop, **kwargs)
#    1052 else:
#    1053     _stop = list(stop)
# -> 1054 result = self([HumanMessage(content=text)], stop=_stop, **kwargs)
#    1055 if isinstance(result.content, str):
#    1056     return result.content
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/langchain_core/_api/deprecation.py:180, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     178     warned = True
#     179     emit_warning()
# --> 180 return wrapped(*args, **kwargs)
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/langchain_core/language_models/chat_models.py:1016, in BaseChatModel.__call__(self, messages, stop, callbacks, **kwargs)
#    1008 @deprecated("0.1.7", alternative="invoke", removal="1.0")
#    1009 def __call__(
#    1010     self,
#    (...)
#    1014     **kwargs: Any,
#    1015 ) -> BaseMessage:
# -> 1016     generation = self.generate(
#    1017         [messages], stop=stop, callbacks=callbacks, **kwargs
#    1018     ).generations[0][0]
#    1019     if isinstance(generation, ChatGeneration):
#    1020         return generation.message
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/langchain_core/language_models/chat_models.py:634, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     632         if run_managers:
#     633             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 634         raise e
#     635 flattened_outputs = [
#     636     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     637     for res in results
#     638 ]
#     639 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/langchain_core/language_models/chat_models.py:624, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     621 for i, m in enumerate(messages):
#     622     try:
#     623         results.append(
# --> 624             self._generate_with_cache(
#     625                 m,
#     626                 stop=stop,
#     627                 run_manager=run_managers[i] if run_managers else None,
#     628                 **kwargs,
#     629             )
#     630         )
#     631     except BaseException as e:
#     632         if run_managers:
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/langchain_core/language_models/chat_models.py:846, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     844 else:
#     845     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 846         result = self._generate(
#     847             messages, stop=stop, run_manager=run_manager, **kwargs
#     848         )
#     849     else:
#     850         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/langchain_community/chat_models/openai.py:473, in ChatOpenAI._generate(self, messages, stop, run_manager, stream, **kwargs)
#     467 message_dicts, params = self._create_message_dicts(messages, stop)
#     468 params = {
#     469     **params,
#     470     **({"stream": stream} if stream is not None else {}),
#     471     **kwargs,
#     472 }
# --> 473 response = self.completion_with_retry(
#     474     messages=message_dicts, run_manager=run_manager, **params
#     475 )
#     476 return self._create_chat_result(response)
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/langchain_community/chat_models/openai.py:384, in ChatOpenAI.completion_with_retry(self, run_manager, **kwargs)
#     382 """Use tenacity to retry the completion call."""
#     383 if is_openai_v1():
# --> 384     return self.client.create(**kwargs)
#     386 retry_decorator = _create_retry_decorator(self, run_manager=run_manager)
#     388 @retry_decorator
#     389 def _completion_with_retry(**kwargs: Any) -> Any:
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/openai/_utils/_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/openai/resources/chat/completions.py:850, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     808 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     809 def create(
#     810     self,
#    (...)
#     847     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     848 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     849     validate_response_format(response_format)
# --> 850     return self._post(
#     851         "/chat/completions",
#     852         body=maybe_transform(
#     853             {
#     854                 "messages": messages,
#     855                 "model": model,
#     856                 "audio": audio,
#     857                 "frequency_penalty": frequency_penalty,
#     858                 "function_call": function_call,
#     859                 "functions": functions,
#     860                 "logit_bias": logit_bias,
#     861                 "logprobs": logprobs,
#     862                 "max_completion_tokens": max_completion_tokens,
#     863                 "max_tokens": max_tokens,
#     864                 "metadata": metadata,
#     865                 "modalities": modalities,
#     866                 "n": n,
#     867                 "parallel_tool_calls": parallel_tool_calls,
#     868                 "prediction": prediction,
#     869                 "presence_penalty": presence_penalty,
#     870                 "reasoning_effort": reasoning_effort,
#     871                 "response_format": response_format,
#     872                 "seed": seed,
#     873                 "service_tier": service_tier,
#     874                 "stop": stop,
#     875                 "store": store,
#     876                 "stream": stream,
#     877                 "stream_options": stream_options,
#     878                 "temperature": temperature,
#     879                 "tool_choice": tool_choice,
#     880                 "tools": tools,
#     881                 "top_logprobs": top_logprobs,
#     882                 "top_p": top_p,
#     883                 "user": user,
#     884             },
#     885             completion_create_params.CompletionCreateParams,
#     886         ),
#     887         options=make_request_options(
#     888             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     889         ),
#     890         cast_to=ChatCompletion,
#     891         stream=stream or False,
#     892         stream_cls=Stream[ChatCompletionChunk],
#     893     )
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/openai/_base_client.py:1283, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1269 def post(
#    1270     self,
#    1271     path: str,
#    (...)
#    1278     stream_cls: type[_StreamT] | None = None,
#    1279 ) -> ResponseT | _StreamT:
#    1280     opts = FinalRequestOptions.construct(
#    1281         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1282     )
# -> 1283     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/openai/_base_client.py:960, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     957 else:
#     958     retries_taken = 0
# --> 960 return self._request(
#     961     cast_to=cast_to,
#     962     options=options,
#     963     stream=stream,
#     964     stream_cls=stream_cls,
#     965     retries_taken=retries_taken,
#     966 )
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/openai/_base_client.py:996, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     993 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     995 try:
# --> 996     response = self._client.send(
#     997         request,
#     998         stream=stream or self._should_stream_response_body(request=request),
#     999         **kwargs,
#    1000     )
#    1001 except httpx.TimeoutException as err:
#    1002     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~/opt/anaconda3/lib/python3.8/ssl.py:1226, in SSLSocket.recv(self, buflen, flags)
#    1222     if flags != 0:
#    1223         raise ValueError(
#    1224             "non-zero flags not allowed in calls to recv() on %s" %
#    1225             self.__class__)
# -> 1226     return self.read(buflen)
#    1227 else:
#    1228     return super().recv(buflen, flags)
#
# File ~/opt/anaconda3/lib/python3.8/ssl.py:1101, in SSLSocket.read(self, len, buffer)
#    1099         return self._sslobj.read(len, buffer)
#    1100     else:
# -> 1101         return self._sslobj.read(len)
#    1102 except SSLError as x:
#    1103     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
# -----------------------------------------------------
# Cell: Extract Details with Enhanced Prompt v3
# -----------------------------------------------------
import os
import json
from typing import Tuple
from langchain.chat_models import ChatOpenAI
from langchain.prompts import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate
)

def parse_system_human_prompt(prompt_file: str) -> Tuple[str, str]:
    """
    Reads a text file containing two sections:
      [System]
      ...some text...
      [Human]
      ...some text...
    Splits them and returns (system_text, human_text).
    """
    with open(prompt_file, 'r', encoding='utf-8') as f:
        full_prompt = f.read()
    if "[System]" not in full_prompt or "[Human]" not in full_prompt:
        raise ValueError("Prompt file must contain both [System] and [Human] sections.")
    
    # Split on "[System]" -> discard anything before it
    _, after_system = full_prompt.split("[System]", 1)
    # Then split on "[Human]"
    system_part, human_part = after_system.split("[Human]", 1)
    return system_part.strip(), human_part.strip()

def load_and_create_chat_prompt(prompt_file: str) -> ChatPromptTemplate:
    """
    Parses a refined prompt file with [System] + [Human] sections
    and creates a ChatPromptTemplate from them.
    """
    system_text, human_text = parse_system_human_prompt(prompt_file)
    return ChatPromptTemplate.from_messages([
        SystemMessagePromptTemplate.from_template(system_text),
        HumanMessagePromptTemplate.from_template(human_text)
    ])

def extract_enhanced_details_realtime(
    base_dir: str,
    output_dir: str,
    output_prefix: str,
    chat_prompt: ChatPromptTemplate,
    chat_model,
):
    """
    Traverses `base_dir` (each top-level subfolder is a 'company'),
    applies a ChatPromptTemplate with system+human messages to each .md file,
    and writes results to separate JSON files in `output_dir`.
    
    Data is written to disk after each file is processed to avoid data loss.
    """
    os.makedirs(output_dir, exist_ok=True)

    for company_folder in os.listdir(base_dir):
        company_path = os.path.join(base_dir, company_folder)
        if not os.path.isdir(company_path):
            continue  # Only process directories

        print(f"\n=== Processing Company: {company_folder} ===")
        company_json_filename = f"{output_prefix}_{company_folder}.json"
        company_json_path = os.path.join(output_dir, company_json_filename)

        # If a JSON file already exists, load it; else start fresh
        if os.path.exists(company_json_path):
            with open(company_json_path, 'r', encoding='utf-8') as cf:
                company_data = json.load(cf)
        else:
            company_data = {}

        # Recursively walk all .md files for the current company
        for root, dirs, files in os.walk(company_path):
            for filename in files:
                if filename.endswith(".md"):
                    file_path = os.path.join(root, filename)
                    rel_path = os.path.relpath(file_path, company_path)

                    try:
                        with open(file_path, 'r', encoding='utf-8') as md_file:
                            markdown_content = md_file.read()

                        # Format the messages
                        # "content" placeholder -> markdown_content
                        messages = chat_prompt.format_messages(content=markdown_content)
                        # Use the LLM
                        response = chat_model(messages).content.strip()

                        # Parse the result
                        # We'll look for lines that start with: 
                        # "Produktname:", "Versicherungsart:", "Deckungssumme:", etc.
                        # If not found, store "Keine Angabe" or an empty list for bullet points.
                        
                        # Default dictionary with possible fields
                        extracted_info = {
                            "Produktname": "Keine Angabe",
                            "Versicherungsart": "Keine Angabe",
                            "Deckungssumme": "Keine Angabe",
                            "Selbstbeteiligung": "Keine Angabe",
                            "Preis": "Keine Angabe",
                            "Gültigkeitsbereich": "Keine Angabe",
                            "Vertragslaufzeit": "Keine Angabe",
                            "Weitere Leistungen": [],
                            "Ausnahmen oder Ausschlüsse": []
                        }
                        
                        # We'll parse line by line
                        current_section = None
                        for line in response.splitlines():
                            line = line.strip()
                            if line.startswith("Produktname:"):
                                extracted_info["Produktname"] = line.replace("Produktname:", "").strip() or "Keine Angabe"
                            elif line.startswith("Versicherungsart:"):
                                extracted_info["Versicherungsart"] = line.replace("Versicherungsart:", "").strip() or "Keine Angabe"
                            elif line.startswith("Deckungssumme:"):
                                extracted_info["Deckungssumme"] = line.replace("Deckungssumme:", "").strip() or "Keine Angabe"
                            elif line.startswith("Selbstbeteiligung:"):
                                extracted_info["Selbstbeteiligung"] = line.replace("Selbstbeteiligung:", "").strip() or "Keine Angabe"
                            elif line.startswith("Preis:"):
                                extracted_info["Preis"] = line.replace("Preis:", "").strip() or "Keine Angabe"
                            elif line.startswith("Gültigkeitsbereich:"):
                                extracted_info["Gültigkeitsbereich"] = line.replace("Gültigkeitsbereich:", "").strip() or "Keine Angabe"
                            elif line.startswith("Vertragslaufzeit:"):
                                extracted_info["Vertragslaufzeit"] = line.replace("Vertragslaufzeit:", "").strip() or "Keine Angabe"
                            elif line.startswith("Weitere Leistungen:"):
                                current_section = "Weitere Leistungen"
                            elif line.startswith("Ausnahmen oder Ausschlüsse:"):
                                current_section = "Ausnahmen oder Ausschlüsse"
                            elif line.startswith("- "):
                                # A bullet point
                                bullet_text = line[2:].strip()
                                if current_section in ["Weitere Leistungen", "Ausnahmen oder Ausschlüsse"]:
                                    extracted_info[current_section].append(bullet_text)

                        # Store in company_data dictionary
                        company_data[rel_path] = extracted_info

                        # Write out the JSON in real-time
                        with open(company_json_path, 'w', encoding='utf-8') as out_f:
                            json.dump(company_data, out_f, ensure_ascii=False, indent=4)

                        print(f"Extrahiert aus {rel_path}: {extracted_info['Produktname']}")

                    except Exception as err:
                        print(f"Fehler bei {rel_path}: {err}")

        print(f"→ Ergebnisse für {company_folder} in {company_json_path}")

# -----------------------------
# MAIN EXECUTION
# -----------------------------
BASE_DIR_V3 = "03_textbinary_products_v2"  # or any folder with .md subfolders
OUTPUT_DIR_V3 = "04_product_details_extraction_v2"
OUTPUT_PREFIX_V3 = "report_full_details_v2"
PROMPT_FILE_V3 = "extract_full_details_prompt_v2.txt"

# 1) Create ChatPromptTemplate from system+human messages
chat_prompt_v3 = load_and_create_chat_prompt(PROMPT_FILE_V3)

# 2) Initialize Chat Model
chat_model_v3 = ChatOpenAI(model="gpt-4o", temperature=0)

# 3) Extract details in real-time, storing them in separate JSON for each company
extract_enhanced_details_realtime(
    base_dir=BASE_DIR_V3,
    output_dir=OUTPUT_DIR_V3,
    output_prefix=OUTPUT_PREFIX_V3,
    chat_prompt=chat_prompt_v3,
    chat_model=chat_model_v3
)

print("\n*** Enhanced Prompt Extraction (v2) completed! ***")
# Out:
# === Processing Company: generali ===
# /var/folders/r4/0py6zcdx7klg7yg0z4ld8z2w0000gn/T/ipykernel_60893/958610468.py:95: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use invoke instead.
#   response = chat_model(messages).content.strip()
# Extrahiert aus privatkunden_rundum-schutz_young-and-drive.md => Produkt: Young & Drive, Details: 8 Einträge
# Extrahiert aus service-kontakt_apps_generali-protect-me-app.md => Produkt: Vermögensaufbau4you, Details: 4 Einträge
# Extrahiert aus geschaeftskunden_gesundheit-betriebliche-vorsorge_betriebliche-krankenversicherung-inland.md => Produkt: Business+ Die betriebliche Krankenversicherung der Generali, Details: 7 Einträge
# Extrahiert aus privatkunden_gesundheit-freizeit_unfallversicherung_unfall-assistance-xxl.md => Produkt: Unfall Assistance XXL, Details: 7 Einträge
# Extrahiert aus privatkunden_gesundheit-freizeit_reise-krankenversicherung.md => Produkt: Generali GesundheitsApp, Details: 9 Einträge
# Extrahiert aus privatkunden_gesundheit-freizeit_wassersportversicherung.md => Produkt: Wassersportversicherung, Details: 7 Einträge
# Extrahiert aus geschaeftskunden_geschaeft-gebaeude_ertragsausfallversicherung.md => Produkt: Ertragsausfallversicherung, Details: 15 Einträge
# Extrahiert aus privatkunden_fahrzeug-zuhause_hausratversicherung.md => Produkt: Hausratversicherung Optimal, Details: 10 Einträge
# Extrahiert aus geschaeftskunden_waren-transport_tiefkuehlgutversicherung.md => Produkt: Tiefkühlgutversicherung, Details: 12 Einträge
# Extrahiert aus geschaeftskunden_gesundheit-betriebliche-vorsorge_direktversicherung.md => Produkt: Direktversicherung, Details: 7 Einträge
# Extrahiert aus geschaeftskunden_geschaeft-gebaeude_sach-inhaltsversicherung.md => Produkt: Immobiliensicherungspolice, Details: 19 Einträge
# Extrahiert aus privatkunden_vorsorge-finanzen_sofort-rente.md => Produkt: Rente Sofort, Details: 7 Einträge
# Extrahiert aus geschaeftskunden_waren-transport_gewerbe-kompakt-mobil.md => Produkt: Gewerbe Kompakt Mobil, Details: 13 Einträge
# Extrahiert aus privatkunden_recht-haftung_rechtsschutzversicherung.md => Produkt: ADVOCARD-360°-PRIVAT, Details: 7 Einträge
# Extrahiert aus geschaeftskunden_geschaeft-gebaeude_elektronikversicherung.md => Produkt: Elektronikversicherung, Details: 13 Einträge
# Extrahiert aus geschaeftskunden_geschaeft-gebaeude_bauversicherungen.md => Produkt: Rohbauversicherung, Details: 12 Einträge
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/umutekingezer/Desktop/NLP_lab/LAB-COMPETITIVE-ANALYSIS/notebooks/poster_presentation/03_extract_details.ipynb Cell 3 line 1
#     <a href='vscode-notebook-cell:/Users/umutekingezer/Desktop/NLP_lab/LAB-COMPETITIVE-ANALYSIS/notebooks/poster_presentation/03_extract_details.ipynb#W3sZmlsZQ%3D%3D?line=135'>136</a> chat_model_v2 = ChatOpenAI(model="gpt-4o", temperature=0)
#     <a href='vscode-notebook-cell:/Users/umutekingezer/Desktop/NLP_lab/LAB-COMPETITIVE-ANALYSIS/notebooks/poster_presentation/03_extract_details.ipynb#W3sZmlsZQ%3D%3D?line=137'>138</a> # Step 3: Extract details in real-time, one JSON per company
# --> <a href='vscode-notebook-cell:/Users/umutekingezer/Desktop/NLP_lab/LAB-COMPETITIVE-ANALYSIS/notebooks/poster_presentation/03_extract_details.ipynb#W3sZmlsZQ%3D%3D?line=138'>139</a> extract_full_details_realtime(
#     <a href='vscode-notebook-cell:/Users/umutekingezer/Desktop/NLP_lab/LAB-COMPETITIVE-ANALYSIS/notebooks/poster_presentation/03_extract_details.ipynb#W3sZmlsZQ%3D%3D?line=139'>140</a>     base_dir=BASE_DIR_V2,
#     <a href='vscode-notebook-cell:/Users/umutekingezer/Desktop/NLP_lab/LAB-COMPETITIVE-ANALYSIS/notebooks/poster_presentation/03_extract_details.ipynb#W3sZmlsZQ%3D%3D?line=140'>141</a>     output_dir=OUTPUT_DIR_V2,
#     <a href='vscode-notebook-cell:/Users/umutekingezer/Desktop/NLP_lab/LAB-COMPETITIVE-ANALYSIS/notebooks/poster_presentation/03_extract_details.ipynb#W3sZmlsZQ%3D%3D?line=141'>142</a>     output_prefix=OUTPUT_PREFIX_V2,
#     <a href='vscode-notebook-cell:/Users/umutekingezer/Desktop/NLP_lab/LAB-COMPETITIVE-ANALYSIS/notebooks/poster_presentation/03_extract_details.ipynb#W3sZmlsZQ%3D%3D?line=142'>143</a>     chat_prompt=chat_prompt_v2,
#     <a href='vscode-notebook-cell:/Users/umutekingezer/Desktop/NLP_lab/LAB-COMPETITIVE-ANALYSIS/notebooks/poster_presentation/03_extract_details.ipynb#W3sZmlsZQ%3D%3D?line=143'>144</a>     chat_model=chat_model_v2
#     <a href='vscode-notebook-cell:/Users/umutekingezer/Desktop/NLP_lab/LAB-COMPETITIVE-ANALYSIS/notebooks/poster_presentation/03_extract_details.ipynb#W3sZmlsZQ%3D%3D?line=144'>145</a> )
#     <a href='vscode-notebook-cell:/Users/umutekingezer/Desktop/NLP_lab/LAB-COMPETITIVE-ANALYSIS/notebooks/poster_presentation/03_extract_details.ipynb#W3sZmlsZQ%3D%3D?line=146'>147</a> print("\n*** Refinement experiment (Cell 2) complete! ***")
#
# /Users/umutekingezer/Desktop/NLP_lab/LAB-COMPETITIVE-ANALYSIS/notebooks/poster_presentation/03_extract_details.ipynb Cell 3 line 9
#      <a href='vscode-notebook-cell:/Users/umutekingezer/Desktop/NLP_lab/LAB-COMPETITIVE-ANALYSIS/notebooks/poster_presentation/03_extract_details.ipynb#W3sZmlsZQ%3D%3D?line=92'>93</a> messages = chat_prompt.format_messages(content=markdown_content)
#      <a href='vscode-notebook-cell:/Users/umutekingezer/Desktop/NLP_lab/LAB-COMPETITIVE-ANALYSIS/notebooks/poster_presentation/03_extract_details.ipynb#W3sZmlsZQ%3D%3D?line=93'>94</a> # Use the LLM
# ---> <a href='vscode-notebook-cell:/Users/umutekingezer/Desktop/NLP_lab/LAB-COMPETITIVE-ANALYSIS/notebooks/poster_presentation/03_extract_details.ipynb#W3sZmlsZQ%3D%3D?line=94'>95</a> response = chat_model(messages).content.strip()
#      <a href='vscode-notebook-cell:/Users/umutekingezer/Desktop/NLP_lab/LAB-COMPETITIVE-ANALYSIS/notebooks/poster_presentation/03_extract_details.ipynb#W3sZmlsZQ%3D%3D?line=96'>97</a> # Parse the result
#      <a href='vscode-notebook-cell:/Users/umutekingezer/Desktop/NLP_lab/LAB-COMPETITIVE-ANALYSIS/notebooks/poster_presentation/03_extract_details.ipynb#W3sZmlsZQ%3D%3D?line=97'>98</a> product_name = None
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/langchain_core/_api/deprecation.py:180, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     178     warned = True
#     179     emit_warning()
# --> 180 return wrapped(*args, **kwargs)
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/langchain_core/language_models/chat_models.py:1016, in BaseChatModel.__call__(self, messages, stop, callbacks, **kwargs)
#    1008 @deprecated("0.1.7", alternative="invoke", removal="1.0")
#    1009 def __call__(
#    1010     self,
#    (...)
#    1014     **kwargs: Any,
#    1015 ) -> BaseMessage:
# -> 1016     generation = self.generate(
#    1017         [messages], stop=stop, callbacks=callbacks, **kwargs
#    1018     ).generations[0][0]
#    1019     if isinstance(generation, ChatGeneration):
#    1020         return generation.message
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/langchain_core/language_models/chat_models.py:634, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     632         if run_managers:
#     633             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 634         raise e
#     635 flattened_outputs = [
#     636     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     637     for res in results
#     638 ]
#     639 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/langchain_core/language_models/chat_models.py:624, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     621 for i, m in enumerate(messages):
#     622     try:
#     623         results.append(
# --> 624             self._generate_with_cache(
#     625                 m,
#     626                 stop=stop,
#     627                 run_manager=run_managers[i] if run_managers else None,
#     628                 **kwargs,
#     629             )
#     630         )
#     631     except BaseException as e:
#     632         if run_managers:
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/langchain_core/language_models/chat_models.py:846, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     844 else:
#     845     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 846         result = self._generate(
#     847             messages, stop=stop, run_manager=run_manager, **kwargs
#     848         )
#     849     else:
#     850         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/langchain_community/chat_models/openai.py:473, in ChatOpenAI._generate(self, messages, stop, run_manager, stream, **kwargs)
#     467 message_dicts, params = self._create_message_dicts(messages, stop)
#     468 params = {
#     469     **params,
#     470     **({"stream": stream} if stream is not None else {}),
#     471     **kwargs,
#     472 }
# --> 473 response = self.completion_with_retry(
#     474     messages=message_dicts, run_manager=run_manager, **params
#     475 )
#     476 return self._create_chat_result(response)
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/langchain_community/chat_models/openai.py:384, in ChatOpenAI.completion_with_retry(self, run_manager, **kwargs)
#     382 """Use tenacity to retry the completion call."""
#     383 if is_openai_v1():
# --> 384     return self.client.create(**kwargs)
#     386 retry_decorator = _create_retry_decorator(self, run_manager=run_manager)
#     388 @retry_decorator
#     389 def _completion_with_retry(**kwargs: Any) -> Any:
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/openai/_utils/_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/openai/resources/chat/completions.py:850, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     808 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     809 def create(
#     810     self,
#    (...)
#     847     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     848 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     849     validate_response_format(response_format)
# --> 850     return self._post(
#     851         "/chat/completions",
#     852         body=maybe_transform(
#     853             {
#     854                 "messages": messages,
#     855                 "model": model,
#     856                 "audio": audio,
#     857                 "frequency_penalty": frequency_penalty,
#     858                 "function_call": function_call,
#     859                 "functions": functions,
#     860                 "logit_bias": logit_bias,
#     861                 "logprobs": logprobs,
#     862                 "max_completion_tokens": max_completion_tokens,
#     863                 "max_tokens": max_tokens,
#     864                 "metadata": metadata,
#     865                 "modalities": modalities,
#     866                 "n": n,
#     867                 "parallel_tool_calls": parallel_tool_calls,
#     868                 "prediction": prediction,
#     869                 "presence_penalty": presence_penalty,
#     870                 "reasoning_effort": reasoning_effort,
#     871                 "response_format": response_format,
#     872                 "seed": seed,
#     873                 "service_tier": service_tier,
#     874                 "stop": stop,
#     875                 "store": store,
#     876                 "stream": stream,
#     877                 "stream_options": stream_options,
#     878                 "temperature": temperature,
#     879                 "tool_choice": tool_choice,
#     880                 "tools": tools,
#     881                 "top_logprobs": top_logprobs,
#     882                 "top_p": top_p,
#     883                 "user": user,
#     884             },
#     885             completion_create_params.CompletionCreateParams,
#     886         ),
#     887         options=make_request_options(
#     888             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     889         ),
#     890         cast_to=ChatCompletion,
#     891         stream=stream or False,
#     892         stream_cls=Stream[ChatCompletionChunk],
#     893     )
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/openai/_base_client.py:1283, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1269 def post(
#    1270     self,
#    1271     path: str,
#    (...)
#    1278     stream_cls: type[_StreamT] | None = None,
#    1279 ) -> ResponseT | _StreamT:
#    1280     opts = FinalRequestOptions.construct(
#    1281         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1282     )
# -> 1283     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/openai/_base_client.py:960, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     957 else:
#     958     retries_taken = 0
# --> 960 return self._request(
#     961     cast_to=cast_to,
#     962     options=options,
#     963     stream=stream,
#     964     stream_cls=stream_cls,
#     965     retries_taken=retries_taken,
#     966 )
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/openai/_base_client.py:996, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     993 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     995 try:
# --> 996     response = self._client.send(
#     997         request,
#     998         stream=stream or self._should_stream_response_body(request=request),
#     999         **kwargs,
#    1000     )
#    1001 except httpx.TimeoutException as err:
#    1002     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Desktop/NLP_lab/kedro_env/lib/python3.8/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~/opt/anaconda3/lib/python3.8/ssl.py:1226, in SSLSocket.recv(self, buflen, flags)
#    1222     if flags != 0:
#    1223         raise ValueError(
#    1224             "non-zero flags not allowed in calls to recv() on %s" %
#    1225             self.__class__)
# -> 1226     return self.read(buflen)
#    1227 else:
#    1228     return super().recv(buflen, flags)
#
# File ~/opt/anaconda3/lib/python3.8/ssl.py:1101, in SSLSocket.read(self, len, buffer)
#    1099         return self._sslobj.read(len, buffer)
#    1100     else:
# -> 1101         return self._sslobj.read(len)
#    1102 except SSLError as x:
#    1103     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
